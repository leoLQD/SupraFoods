# %% [markdown]
# # Análise de Produtos

# %%
import pandas as pd
import numpy as np
import locale
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Define Moeda Brasileira numeros R$ 1.000,00
#locale.setlocale( locale.LC_ALL, '' )
#locale.currency( g, grouping = True )

# %%
from numpy.random import randn
#np.random.seed(101)

# %%
#pd.options.display.float_format = 'R${:,.2f}'.format

# %%
# Abre o Arquivo de Notas Fiscais
# Forço o tipo das Colunas COD, NF e CNPJ como String se não abrem como Numérico
df = pd.read_csv('NFe-SupraAlimentos.csv', dtype={'cod': object, 'NF': object, 'CNPJ': object})

# %%
# Exclui a primeira coluna uma vez q tem erros de digitação. 
# Com isso evita o mesmo código com descrições diferentes
df.drop('descricao',axis=1,inplace=True)

# %%
# Tipo das Columas
df.dtypes
# Out:
# cliente     object
# NF          object
# data        object
# CNPJ        object
# cidade      object
# bairro      object
# UF          object
# cod         object
# QTY          int64
# unidade     object
# preco      float64
# dtype: object

# %%
df.head()
# Out:
#                                              cliente NF        data  \
# 0  NF-E EMITIDA EM AMBIENTE DE HOMOLOGACAO - SEM ...  4  2014-08-29
# 1  NF-E EMITIDA EM AMBIENTE DE HOMOLOGACAO - SEM ...  5  2014-08-29
# 2  NF-E EMITIDA EM AMBIENTE DE HOMOLOGACAO - SEM ...  6  2014-08-29
# 3  NF-E EMITIDA EM AMBIENTE DE HOMOLOGACAO - SEM ...  6  2014-08-29
# 4  NF-E EMITIDA EM AMBIENTE DE HOMOLOGACAO - SEM ...  6  2014-08-29
#
#              CNPJ          cidade               bairro  UF     cod  QTY  \
# 0  27833615002018  RIO DE JANEIRO    CASIMIRO DE ABREU  RJ  020002    1
# 1  09309021000168  RIO DE JANEIRO  VILA NOVA DE CAMPOS  RJ  010002    1
# 2  09309021000168  ANGRA DOS REIS  VILA NOVA DE CAMPOS  RJ  010001   12
# 3  09309021000168  ANGRA DOS REIS  VILA NOVA DE CAMPOS  RJ  010002    1
# 4  09309021000168  ANGRA DOS REIS  VILA NOVA DE CAMPOS  RJ  010009    1
#
#   unidade  preco
# 0      UN   2.77
# 1      UN   1.11
# 2      UN   9.72
# 3      UN   1.11
# 4      UN   1.43

# %% [markdown]
# # Cria Arquivo de Produtos

# %%
# Classifica a Familia de Produtos em Função do CÓDIGO
def famProdutos(xCod):
    x = str(xCod)
    yCod = x[:2]
    if yCod == '01':
        return 'Blister'
    elif yCod =='02':
        return 'Temperos'
    elif yCod =='03':
        return 'Molhos'
    elif yCod == '04':
        return 'Conservas'
    elif yCod =='05': 
        return 'Institucional'
    elif yCod == '06':
        return 'Diversos '
    elif yCod =='07':
        return 'Insumos'
    elif yCod =='08':
        return 'Consumo'
    elif yCod == '09':
        return 'Produtos Prontos para Venda'
    elif yCod =='10':
        return 'Serviço'
    elif yCod == '11':
        return 'Embalagens'
    elif yCod =='12':
        return 'Contas Fixas'
    elif yCod == '13':
        return 'Bem Ativo'
    elif yCod =='14':
        return 'Manutenção de Ativo'
    elif yCod =='15':
        return 'Display'
    elif yCod == '16':
        return 'Supra Life'

# %% [markdown]
# ###### Carrega Tabela de Produtos

# %%
nomes = pd.read_csv('supraProdutos.csv', dtype={'cod': object, 'descricao': object}, encoding='latin-1')

# %%
# Acrescenta nome da Familia de Produtos
nomes['Familia'] = nomes['cod'].apply(famProdutos)

# %%
nomes.head()
# Out:
#       cod             descricao  Familia
# 0  000001               BLISTER     None
# 1  010001          ACAFRAO 15GR  Blister
# 2  010002          ALECRIM 15GR  Blister
# 3  010003  ALFAVACA MOIDA  15GR  Blister
# 4  010004       ALHO FRITO 30GR  Blister

# %%
# Fazendo um Merge dos DataSets para incluir a descrição correta e a família de Produtos nas NFe
notaFiscal = pd.merge(df, nomes, left_on = 'cod', right_on = 'cod')

# %%
notaFiscal.tail()
# Out:
#                                    cliente    NF        data            CNPJ  \
# 160601  PORTAL DO EDEN COMERCIAL ALIM LTDA  7952  2018-02-03  07384953000140
# 160602  PORTAL DO EDEN COMERCIAL ALIM LTDA  7952  2018-02-03  07384953000140
# 160603  PORTAL DO EDEN COMERCIAL ALIM LTDA  7952  2018-02-03  07384953000140
# 160604  PORTAL DO EDEN COMERCIAL ALIM LTDA  7952  2018-02-03  07384953000140
# 160605  PORTAL DO EDEN COMERCIAL ALIM LTDA  7952  2018-02-03  07384953000140
#
#                 cidade bairro  UF     cod  QTY unidade  preco  \
# 160601  RIO DE JANEIRO  IRAJA  RJ  050167    5      CX  239.8
# 160602  RIO DE JANEIRO  IRAJA  RJ  050168    5      CX  228.5
# 160603  RIO DE JANEIRO  IRAJA  RJ  050169    5      CX  228.5
# 160604  RIO DE JANEIRO  IRAJA  RJ  050170    5      CX  228.5
# 160605  RIO DE JANEIRO  IRAJA  RJ  050171    5      CX  228.5
#
#                                    descricao        Familia
# 160601        MOLHO P/  GRELHADOS  12X1.010L  Institucional
# 160602  MOLHO DE ALHO  C/ PIMENTA  12X1.010L  Institucional
# 160603    MOLHO DE  PIMENTA VERDE  12X1.010L  Institucional
# 160604   MOLHO DE  PIMENTA VULCÃO  12X1.010L  Institucional
# 160605  MOLHO DE  PIMENTA AMARELA  12X1.010L  Institucional

# %% [markdown]
# #### Cria um Novo arquivo CSV de NFs com todas as Descrições corretas

# %%
notaFiscal.to_csv('NFe-Supra.csv',encoding='utf-8', index=False)   # ,encoding='utf-8', index=False Grava CSV sem o Indice

# %%
df1 = pd.read_csv('NFe-Supra.csv', dtype={'cod': object, 'NF': object, 'CNPJ': object})

# %%
df1.head()
# Out:
#                                              cliente    NF        data  \
# 0  NF-E EMITIDA EM AMBIENTE DE HOMOLOGACAO - SEM ...     4  2014-08-29
# 1          TOP GREEN FRUIT HORTIFRUITGRANJEIROS LTDA  1275  2014-10-04
# 2            M L ZIELINSKI LANCHONETE E CONVENIENCIA  1285  2014-10-09
# 3                NOVA ESPERANCA DE ARARUAMA LTDA EPP  1294  2014-10-14
# 4                  SUPERMERCADO SAO JUDAS TADEU LTDA  1296  2014-10-14
#
#              CNPJ          cidade             bairro  UF     cod  QTY unidade  \
# 0  27833615002018  RIO DE JANEIRO  CASIMIRO DE ABREU  RJ  020002    1      UN
# 1  09642314000162        ARARUAMA             CENTRO  RJ  020002   24      UN
# 2  20815576000114           MACAE          SOL E MAR  RJ  020002    2      UN
# 3  05054332000172        ARARUAMA           MATARUNA  RJ  020002   18      UN
# 4  09653290000147       SAQUAREMA             BACAXA  RJ  020002   12      UN
#
#    preco                              descricao   Familia
# 0   2.77  ALHO E CEBOLA  PICADINHO S/SAL  180GR  Temperos
# 1  66.48  ALHO E CEBOLA  PICADINHO S/SAL  180GR  Temperos
# 2   5.54  ALHO E CEBOLA  PICADINHO S/SAL  180GR  Temperos
# 3  49.86  ALHO E CEBOLA  PICADINHO S/SAL  180GR  Temperos
# 160579  09722020000140               MACAE      BARRA DE MACAE  RJ  040024
# 160580  05368841000170         NOVA IGUACU             PARAISO  RJ  040024
# 160581  07258484000112           SAQUAREMA              BACAXA  RJ  050115
# 160582  07258484000112           SAQUAREMA              BACAXA  RJ  050149
# 160583  07258484000112           SAQUAREMA              BACAXA  RJ  050149
# 160584  07258484000112           SAQUAREMA              BACAXA  RJ  050148
# 160585  07258484000112           SAQUAREMA              BACAXA  RJ  050148
# 160586  07258484000112           SAQUAREMA              BACAXA  RJ  050147
# 160587  07258484000112           SAQUAREMA              BACAXA  RJ  050147
# 160588  07258484000112           SAQUAREMA              BACAXA  RJ  050154
# 160589  07384953000140      RIO DE JANEIRO               IRAJA  RJ  050155
# 160590  07384953000140      RIO DE JANEIRO               IRAJA  RJ  050156
# 160591  07384953000140      RIO DE JANEIRO               IRAJA  RJ  050157
# 160592  07384953000140      RIO DE JANEIRO               IRAJA  RJ  050158
# 160593  07384953000140      RIO DE JANEIRO               IRAJA  RJ  050159
# 160594  07384953000140      RIO DE JANEIRO               IRAJA  RJ  050160
# 160595  07384953000140      RIO DE JANEIRO               IRAJA  RJ  050161
# 160596  07384953000140      RIO DE JANEIRO               IRAJA  RJ  050162
# 160597  07384953000140      RIO DE JANEIRO               IRAJA  RJ  050163
# 160598  07384953000140      RIO DE JANEIRO               IRAJA  RJ  050164
# 160599  07384953000140      RIO DE JANEIRO               IRAJA  RJ  050165
# 160600  07384953000140      RIO DE JANEIRO               IRAJA  RJ  050166
# 160601  07384953000140      RIO DE JANEIRO               IRAJA  RJ  050167
# 160602  07384953000140      RIO DE JANEIRO               IRAJA  RJ  050168
# 160603  07384953000140      RIO DE JANEIRO               IRAJA  RJ  050169
# 160604  07384953000140      RIO DE JANEIRO               IRAJA  RJ  050170
# 160605  07384953000140      RIO DE JANEIRO               IRAJA  RJ  050171
#
#         QTY unidade   preco                                     descricao  \
# 160506    3      UN    7.20    MOLHO DE  PIMENTA  BIQUINHO  CREMOSO 150ML
# 160507    3      UN    7.20    MOLHO DE  PIMENTA  BIQUINHO  CREMOSO 150ML
# 160508    3      UN    7.20    MOLHO DE  PIMENTA  BIQUINHO  CREMOSO 150ML
# 160509    3      UN    7.20    MOLHO DE  PIMENTA  BIQUINHO  CREMOSO 150ML
# 160510    6      UN   14.39    MOLHO DE  PIMENTA  BIQUINHO  CREMOSO 150ML
# 160511    1      UN   62.37         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160512    1      UN   62.37         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160513    1      UN   62.37         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160514    1      UN   42.95         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160515    1      CX   42.95         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160516    2      CX   83.33         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160517    2      CX   85.90         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160518    1      CX   42.95         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160519    5      CX  149.99         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160520    1      CX   41.66         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160521    1      CX   41.66         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160522    1      CX   38.21         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160523    1      CX   42.95         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160524    1      CX   42.95         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160525    2      CX   85.90         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160526    2      CX   85.90         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160527    1      CX   41.66         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160528    1      CX   41.66         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160529    1      CX   41.66         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160530    1      CX   41.66         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160531    1      CX   41.66         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160532    1      CX   41.66         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160533    1      CX   28.62         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160534   10      CX  311.77         KETCHUP  TRADICIONAL  200G CX 24 UNID
# 160535    1      CX   28.62         KETCHUP  TRADICIONAL  200G CX 24 UNID
# ...     ...     ...     ...                                           ...
# 160576    1      UN   27.39                    SALSA  DESIDRATADA   500GR
# 160577    1      UN   27.39                    SALSA  DESIDRATADA   500GR
# 160578    1      UN   27.39                    SALSA  DESIDRATADA   500GR
# 160579    6      UN   81.72                      AZEITE DE DENDÊ  1.010KG
# 160580   12      UN  163.44                      AZEITE DE DENDÊ  1.010KG
# 160581    6      UN  102.78                        MOLHO SHOYU  3.100 LTS
# 160582    6      UN   28.74                 CALDO DE BACON  FOODS 1.010KG
# 160583    6      UN   32.94                 CALDO DE BACON  FOODS 1.010KG
# 160584    6      UN   28.74                 CALDO DE CARNE  FOODS 1.010KG
# 160585    6      UN   32.94                 CALDO DE CARNE  FOODS 1.010KG
# 160586    6      UN   28.74              CALDO DE  GALINHA FOODS  1.010KG
# 160587    6      UN   32.94              CALDO DE  GALINHA FOODS  1.010KG
# 160588    4      UN   57.96                         PIMENTA  BIQUINHO 2KG
# 160589    5      FD  303.65                             OREGANO  36X6X20G
# 160590    5      FD  199.10                          MANJERICÃO  36X6X10G
# 160591    5      FD  184.00                               HORTELÃ 36X6X6G
# 160592    5      FD  341.50                      GENGIBRE EM PÓ  36X6X20G
# 160593    5      FD  238.15                         ERVAS FINAS  36X6X10G
# 160594    5      FD  470.00                          ALHO FRITO  36X6X30G
# 160595    5      FD  341.50                      ALHO EM FLOCOS  36X6X20G
# 160596    5      FD  138.60                       COENTRO MOIDO  36X6X10G
# 160597    5      FD  225.50                                CURRY 36X6X15G
# 160598    5      FD  260.80  CALDO DE  BACALHAU C/  ERVAS FINAS  36X6X60G
# 160599    5      FD  260.80   CALDO DE  CAMARÃO C/  ERVAS FINAS  36X6X60G
# 160600    5      FD  260.80      CALDO DE PEIXE  C/ ERVAS FINAS  36X6X60G
# 160601    5      CX  239.80                MOLHO P/  GRELHADOS  12X1.010L
# 160602    5      CX  228.50          MOLHO DE ALHO  C/ PIMENTA  12X1.010L
# 160603    5      CX  228.50            MOLHO DE  PIMENTA VERDE  12X1.010L
# 160604    5      CX  228.50           MOLHO DE  PIMENTA VULCÃO  12X1.010L
# 160605    5      CX  228.50          MOLHO DE  PIMENTA AMARELA  12X1.010L
#
#               Familia
# 160506         Molhos
# 160507         Molhos
# 160508         Molhos
# 160509         Molhos
# 160510         Molhos
# 160511         Molhos
# 160512         Molhos
# 160513         Molhos
# 160514         Molhos
# 160515         Molhos
# 160516         Molhos
# 160517         Molhos
# 160518         Molhos
# 160519         Molhos
# 160520         Molhos
# 160521         Molhos
# 160522         Molhos
# 160523         Molhos
# 160524         Molhos
# 160525         Molhos
# 160526         Molhos
# 160527         Molhos
# 160528         Molhos
# 160529         Molhos
# 160530         Molhos
# 160531         Molhos
# 160532         Molhos
# 160533         Molhos
# 160534         Molhos
# 160535         Molhos
# ...               ...
# 160576  Institucional
# 160577  Institucional
# 160578  Institucional
# 160579      Conservas
# 160580      Conservas
# 160581  Institucional
# 160582  Institucional
# 160583  Institucional
# 160584  Institucional
# 160585  Institucional
# 160586  Institucional
# 160587  Institucional
# 160588  Institucional
# 160589  Institucional
# 160590  Institucional
# 160591  Institucional
# 160592  Institucional
# 160593  Institucional
# 160594  Institucional
# 160595  Institucional
# 160596  Institucional
# 160597  Institucional
# 160598  Institucional
# 160599  Institucional
# 160600  Institucional
# 160601  Institucional
# 160602  Institucional
# 160603  Institucional
# 160604  Institucional
# 160605  Institucional
#
# [100 rows x 13 columns]

# %%
#compraDeClientes = df[['CNPJ','preco']].groupby([df['CNPJ']]).sum().reset_index()
produtosVendidos = df1[['cod']].groupby([df1['cod']]).size().to_frame('qty').reset_index()
#produtosVendidos.sort_values(by=['preco'],ascending=False, na_position='first').reset_index(drop=True)

# %%
produtosVendidos=produtosVendidos.sort_values(by=['qty'],ascending=False, na_position='first').reset_index(drop=True).head()

# %%
produtosVendidos.head()
# Out:
#       cod   qty
# 0  010030  2053
# 1  010031  2017
# 2  010038  1999
# 3  010001  1938
# 4  010010  1907

# %%
# Faz o MERGE dos dois Datasets
s1 = pd.merge(nomes, produtosVendidos, how='inner', on=['cod'])

# %%
s1=s1.sort_values(by=['cod'],ascending=True, na_position='first').reset_index(drop=True)

# %%
len(s1)
# Out:
# 445

# %%
s1.tail(200)
# Out:
#         cod                                      descricao  \
# 245  030039    MOLHO DE  PIMENTA AMARELA  150ML CX 24 UNID
# 246  030041      MOLHO DE  PIMENTA VERDE  150ML CX 24 UNID
# 247  030045              MOLHO DE  PIMENTA VULCÃO  1.010KG
# 248  030047                         MOLHO DE ALHO  1.010KG
# 249  030048               MOLHO DE SALSA  150ML CX 24 UNID
# 250  030049           MOLHO P/  CHURRASCO  150ML CX 24UNID
# 251  030050                 MOLHO INGLES  150ML CX 24 UNID
# 252  030051                  MOLHO SHOYU  150ML CX 24 UNID
# 253  030063                      MOLHO P/  GRELHADOS 145ML
# 254  030064          MOLHO P/  GRELHADOS 145ML  CX 24 UNID
# 255  030068                MOLHO DE  PIMENTA VULCAO  150ML
# 256  030069     MOLHO DE  PIMENTA VULCAO  150ML CX 24 UNID
# 257  030070         MOLHO DE ALHO  C/ ERVAS FINAS  1.010KG
# 258  030071             MOLHO DE ALHO  C/ PIMENTA  1.010KG
# 259  030072                           MOLHO ÁRABE  1.010KG
# 260  030073          MOLHO DE  PIMENTA  CALABRESA  1.010KG
# 261  030074                      MOLHO DE  PIMENTA 1.010KG
# 262  030075                   MOLHO P/  CHURRASCO  1.010KG
# 263  030076                          MOLHO INGLÊS  1.010KG
# 264  030077                           MOLHO SHOYU  1.010KG
# 265  030078                   MOLHO P/  GRELHADOS  1.010KG
# 266  030079                       MOLHO DE CEBOLA  1.010KG
# 267  030080               MOLHO DE  PIMENTA VERDE  1.010KG
# 268  030081             MOLHO DE  PIMENTA AMARELA  1.010KG
# 269  030082                      KETCHUP  TRADICIONAL 200G
# 270  030083                      KETCHUP  TRADICIONAL 400G
# 271  030084                           MOLHO BARBECUE  200G
# 272  030085                                  MOSTARDA 200G
# 273  030086     MOLHO DE  PIMENTA  VERMELHA  CREMOSO 150ML
# 274  030087       MOLHO DE  PIMENTA C/ AÇAÍ  CREMOSO 150ML
# ..      ...                                            ...
# 415  050167                 MOLHO P/  GRELHADOS  12X1.010L
# 416  050168           MOLHO DE ALHO  C/ PIMENTA  12X1.010L
# 417  050169             MOLHO DE  PIMENTA VERDE  12X1.010L
# 418  050170            MOLHO DE  PIMENTA VULCÃO  12X1.010L
# 419  050171           MOLHO DE  PIMENTA AMARELA  12X1.010L
# 420  060022       MIXER/TRITURADO MP450 ULTRA EP  220/60/1
# 421  060339            PAPEL CHAMEX  216X279 10X500  CARTA
# 422  060521                                              ?
# 423  060522                                              ?
# 424  070016                     ALHO GRAN 8/16  25KG -- 52
# 425  070032                             PAPRICA DOCE  10KG
# 426  070068            CONFEITO  COLORIDO  GRANULADO 25 KG
# 427  070096                       OREGANO  PERUANO 12.5 KG
# 428  070113                      ACAFRAO PURO  MOIDO 25 KG
# 429  070115                                 CANELA PO PURA
# 430  070139                           EDTA DISSODICO  25KG
# 431  070175                        TOMATE SECO  TURCO 10KG
# 432  070204                                    LOURO TURCO
# 433  070209                    PO DE CACAU  ALCALINO BLACK
# 434  070252                     COENTRO  SEMENTE 25 KG - S
# 435  080025                           ENVASADORA  (PARTES)
# 436  090095                  CANELA EM PO  20G (TUBO) T.P.
# 437  090098       PIMENTA DO  REINO EM PO 40G  (TUBO) T.P.
# 438  100268                            PESADORA  HELIMATIC
# 439  100279                       DOSADOR SEMI  AUTOMATICO
# 440  110020  POTE 220ML -  REDONDO C/ ALÇA  - SOMENTE POTE
# 441  140002           BOMBA DE  PARAFUSO.  USADO NO ESTADO
# 442  140003  BOMBA DE  PARAFUSO  PEQUENA. USADO  NO ESTADO
# 443  140004                TANQUE PULMÃO.  USADO NO ESTADO
# 444  140005          TANQUE EM AÇO  INOX. USADO NO  ESTADO
#
#                          Familia  qty
# 245                       Molhos   65
# 246                       Molhos  125
# 247                       Molhos   77
# 248                       Molhos  150
# 249                       Molhos  259
# 250                       Molhos  274
# 251                       Molhos  675
# 252                       Molhos  585
# 253                       Molhos  284
# 254                       Molhos  145
# 255                       Molhos  923
# 256                       Molhos  667
# 257                       Molhos   73
# 258                       Molhos   29
# 259                       Molhos    7
# 260                       Molhos    8
# 261                       Molhos   82
# 262                       Molhos   28
# 263                       Molhos  162
# 264                       Molhos  150
# 265                       Molhos   22
# 266                       Molhos    2
# 267                       Molhos    5
# 268                       Molhos    1
# 269                       Molhos  144
# 270                       Molhos   64
# 271                       Molhos  268
# 272                       Molhos  152
# 273                       Molhos   86
# 274                       Molhos  109
# ..                           ...  ...
# 415                Institucional    1
# 416                Institucional    1
# 417                Institucional    1
# 418                Institucional    1
# 419                Institucional    1
# 420                    Diversos     1
# 421                    Diversos     1
# 422                    Diversos     2
# 423                    Diversos     3
# 424                      Insumos    1
# 425                      Insumos    1
# 426                      Insumos    1
# 427                      Insumos    1
# 428                      Insumos    1
# 429                      Insumos    1
# 430                      Insumos    1
# 431                      Insumos    2
# 432                      Insumos    6
# 433                      Insumos    1
# 434                      Insumos    1
# 435                      Consumo    2
# 436  Produtos Prontos para Venda    1
# 437  Produtos Prontos para Venda    1
# 438                      Serviço    1
# 439                      Serviço    1
# 440                   Embalagens    4
# 441          Manutenção de Ativo    2
# 442          Manutenção de Ativo    2
# 443          Manutenção de Ativo    2
# 444          Manutenção de Ativo    2
#
# [200 rows x 4 columns]

# %%
s2=s1.drop_duplicates(subset='cod', keep="last").reset_index(drop=True) #.drop_duplicates()

# %%
s2.tail()

# %% [markdown]
# # Numero de Clientes comprando por Mês

# %%
dados = df.groupby([df['data'].str[0:7],df['cod']]).size()

# %%
df[df['cod']==1]  # df[(df['W']>0) & (df['Y'] > 1)]

# %%
dados = df.groupby(df['cod']).size()

# %%
# Convertendo de Série p/ dataframe
d = dados.to_frame().reset_index()

# %%
e=d.columns

# %%
f= d.sort_values(by=[0],ascending=False, na_position='first').reset_index(drop=True)

# %%
f

# %%
# 160029
#f['cod']==30112
f[f['cod'] == int(str(160001)[:2])]

# %%
g=str(160001)[:2]

# %%
g

# %%
d

# %%
# Número de Clientes por Mês
numClientes = d.groupby('data').size()
numClientes.head()

# %%
# Número médio de Clientes
a=(numClientes.mean())

# %%
int(a)

# %%
numC = numClientes.plot( x=numClientes, stacked=True, kind='bar', figsize=(20,7), rot=90, legend=False, facecolor='#AA0000')

numC.set_xlabel('Mês')
numC.set_ylabel('Número de Clientes')
numC.set_title('Clientes Ativos')
numC.axhline( y=a, color='g', linestyle='--', lw=2, label='Valor Médio')
