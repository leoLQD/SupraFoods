# %%
from pymongo import MongoClient

# %%
client = MongoClient()

# %%
db = client.monix

# %%
collection = db.posts

# %%
int=db.collection.find({}).count()

# %%
int
# Out:
# 0

# %%
post={
        "created_time": "2017-11-03T15:00:00+0000",
        "message": "Anthelios AIRlicium controla a oleosidade, a umidade e oferece muito alta proteção para a pele. Conta pra gente: qual é o benefício que irá deixá-lo ideal para o seu dia a dia?",
        "id": "508638082532356_1602039613192192"
      }

# %%
post_id
# Out:
# ObjectId('59fcee7e439a70133041dee4')

# %%
import pprint
pprint.pprint(collection.find_one())
# Out:
# {'_id': ObjectId('59fcee7e439a70133041dee4'),
#  'created_time': '2017-11-03T15:00:00+0000',
#  'id': '508638082532356_1602039613192192',
#  'message': 'Anthelios AIRlicium controla a oleosidade, a umidade e oferece '
#             'muito alta proteção para a pele. Conta pra gente: qual é o '
#             'benefício que irá deixá-lo ideal para o seu dia a dia?'}

# %%
post={
        "created_time": "2017-11-02T23:00:00+0000",
        "message": "O que é o Cicaplast Baume B5 e qual a sua indicação? Confira!",
        "id": "508638082532356_1601423173253836"
      }

# %%
pprint.pprint(collection.find_one())
# Out:
# {'_id': ObjectId('59fcee7e439a70133041dee4'),
#  'created_time': '2017-11-03T15:00:00+0000',
#  'id': '508638082532356_1602039613192192',
#  'message': 'Anthelios AIRlicium controla a oleosidade, a umidade e oferece '
#             'muito alta proteção para a pele. Conta pra gente: qual é o '
#             'benefício que irá deixá-lo ideal para o seu dia a dia?'}

# %%
new_posts=[{
        "created_time": "2017-11-02T23:00:00+0000",
        "message": "O que é o Cicaplast Baume B5 e qual a sua indicação? Confira!",
        "id": "508638082532356_1601423173253836"
      },
      {
        "created_time": "2017-11-02T19:00:00+0000",
        "message": "Lipikar Creme AOX combina ação antioxidante com hidratação profunda em uma textura leve de rápida absorção. Além disso, mantém sua pele sempre protegida contra os raios UV, com FPS 60. Já experimentou? Nos conte o que achou! 😉",
        "id": "508638082532356_1601265756602911"
      }]

# %%
result = collection.insert_many(new_posts)

# %%
result.inserted_ids
# Out:
# [ObjectId('59fd0dbd439a70133041dee5'), ObjectId('59fd0dbd439a70133041dee6')]

# %%
for post in collection.find():
 pprint.pprint(post)
# Out:
# {'_id': ObjectId('59fcee7e439a70133041dee4'),
#  'created_time': '2017-11-03T15:00:00+0000',
#  'id': '508638082532356_1602039613192192',
#  'message': 'Anthelios AIRlicium controla a oleosidade, a umidade e oferece '
#             'muito alta proteção para a pele. Conta pra gente: qual é o '
#             'benefício que irá deixá-lo ideal para o seu dia a dia?'}
# {'_id': ObjectId('59fd0dbd439a70133041dee5'),
#  'created_time': '2017-11-02T23:00:00+0000',
#  'id': '508638082532356_1601423173253836',
#  'message': 'O que é o Cicaplast Baume B5 e qual a sua indicação? Confira!'}
# {'_id': ObjectId('59fd0dbd439a70133041dee6'),
#  'created_time': '2017-11-02T19:00:00+0000',
#  'id': '508638082532356_1601265756602911',
#  'message': 'Lipikar Creme AOX combina ação antioxidante com hidratação '
#             'profunda em uma textura leve de rápida absorção. Além disso, '
#             'mantém sua pele sempre protegida contra os raios UV, com FPS 60. '
# ...

# %%
clientes = db.clientes

# %%
empresa = {
  "global_brand_page_name": "La Roche-Posay",
  "fan_count": 4956858,
  "category": "Beauty Store",
  "about": "Um canal de troca de experiências e dicas de saúde para quem sabe que uma pele bem cuidada é a base de qualquer beleza. Visite: www.laroche-posay.com.br",
  "birthday": "04/29/2013",
  "website": "http://www.laroche-posay.com.br",
  "name": "La Roche-Posay",
  "products": "Com uma experiência de mais de 30 anos de pesquisa e 25 patentes, a La Roche-Posay se tornou referência no desenvolvimento de produtos dedicados à pele, principalmente as mais sensíveis. As soluções vão desde cuidados para o rosto e corpo até maquiagem e cabelos. Veja as nossas linhas: http://bit.ly/10hYJkm",
  "talking_about_count": 53592,
  "username": "LaRocheBrasil",
  "id": "508638082532356"
}

# %%
c = db.empresa

# %%
empresa_id = c.insert_one(empresa).inserted_id

# %%
print(msgs['posts']['data'][1]['message'])

# %%
posts = [{
        "created_time": "2017-11-03T22:30:00+0000",
        "message": "Cicaplast Lábios repara, hidrata e alivia a pele dos lábios. Por isso, é o escolhido da @larissaqcarvalho! Experimente!",
        "id": "508638082532356_1602339643162189"
      },
      {
        "created_time": "2017-11-03T20:30:00+0000",
        "message": "Descubra como se dá a eficácia antiacne do produto:",
        "id": "508638082532356_1602270523169101"
      },
      {
        "created_time": "2017-11-02T14:30:00+0000",
        "message": "Veja dicas de como usar o filtro solar ao longo do ano e no dia a dia:",
        "id": "508638082532356_1601079296621557"
      },
      {
        "created_time": "2017-11-01T22:40:00+0000",
        "message": "Manipular espinhas, pegar sol e passar a mão no rosto são alguns hábitos que pessoas com a pele acneica devem evitar. Confira como cuidar da sua pele:",
        "id": "508638082532356_1600417510021069"
      },
      {
        "created_time": "2017-11-01T20:00:00+0000",
        "message": "Confira dicas de como minimizar a aparência das rugas:",
        "id": "508638082532356_1600324453363708"
      },
      {
        "created_time": "2017-11-01T14:15:00+0000",
        "message": "Conta pra gente: como você escolhe o seu protetor solar?",
        "id": "508638082532356_1600065930056227"
      },
      {
        "created_time": "2017-10-31T22:00:00+0000",
        "message": "Os principais efeitos de envelhecimento que a pele do corpo sofre são ressecamento, descamação, rugas, manchas e flacidez. Confira como combatê-los:",
        "id": "508638082532356_1599413270121493"
      },
      {
        "created_time": "2017-10-31T20:20:00+0000",
        "message": "Com textura bálsamo não oleosa, Cicaplast Baume B5 de La Roche-Posay cuida profundamente sem deixar uma sensação pegajosa. Fácil de espalhar, irá hidratar e reparar sua pele. Experimente! 😉",
        "id": "508638082532356_1599328363463317"
      },
      {
        "created_time": "2017-10-31T17:15:00+0000",
        "message": "Você sabe quais são os alimentos que podem interferir na saúde da sua pele? Confira:",
        "id": "508638082532356_1599096990153121"
      },
      {
        "created_time": "2017-10-31T15:00:01+0000",
        "message": "Dermatologista explica o que é o melasma e quais são as causas:",
        "id": "508638082532356_1598976723498481"
      },
      {
        "created_time": "2017-10-31T13:00:00+0000",
        "message": "Quer ter uma pele mais firme? Confira:",
        "id": "508638082532356_1598842260178594"
      },
      {
        "created_time": "2017-10-30T22:40:00+0000",
        "message": "Saiba como proteger a pele contra a radiação solar mesmo em dia nublados:",
        "id": "508638082532356_1574143342648486"
      },
      {
        "created_time": "2017-10-14T00:15:21+0000",
        "message": "Fique atenta aos sinais do seu corpo. O auto-exame e a observação atenta da mama são fundamentais para o diagnóstico precoce. Se descoberto ainda no início, as chances de cura aumentam em até 95%. Previna-se!",
        "id": "508638082532356_1581308261931994"
      },
      {
        "created_time": "2017-10-13T21:00:00+0000",
        "message": "Você está cansada de ficar com aquele aspecto brilhoso no rosto? Confira dicas:",
        "id": "508638082532356_1581200641942756"
      },
      {
        "created_time": "2017-10-13T16:00:00+0000",
        "message": "Effaclar Alta Tolerância ou Effaclar Concentrado: qual deles faz parte da sua rotina? Conta pra gente!",
        "id": "508638082532356_1580997701963050"
      },
      {
        "created_time": "2017-10-12T22:30:29+0000",
        "message": "La Roche-Posay cuida da pele sensível das crianças, com produtos que são testados sob controle dermatológico e pediátrico e especializados, para que não falte disposição para brincar. Feliz Dia das Crianças!",
        "id": "508638082532356_1579682812094539"
      },
      {
        "created_time": "2017-10-12T18:00:00+0000",
        "message": "O protetor solar do corpo pode ser usado no rosto? Confira:",
        "id": "508638082532356_1574141182648702"
      },
      {
        "created_time": "2017-10-12T15:10:16+0000",
        "message": "La Roche-Posay cuida da pele dos pequenos para que não falte brincadeiras e diversão. Feliz Dia das Crianças!",
        "id": "508638082532356_1579677405428413"
      },
      {
        "created_time": "2017-10-11T15:00:00+0000",
        "message": "Você sabe como proteger sua pele contra os danos do sol? Confira: http://bit.ly/2y53CcB",
        "id": "508638082532356_1574164719313015"
      },
      {
        "created_time": "2017-10-09T15:00:00+0000",
        "message": "Cheque suas pintas e de quem você ama!",
        "id": "508638082532356_1574160665980087"
      },
      {
        "created_time": "2017-10-08T21:00:00+0000",
        "message": "O câncer de pele ainda é o tipo mais comum no Brasil! Confira como cuidar da sua saúde:",
        "id": "508638082532356_1574136512649169"
      },
      {
        "created_time": "2017-10-08T16:00:00+0000",
        "message": "Segundo o Instituto Nacional de Câncer (INCA), o câncer de pele é responsável por cerca de 25% dos tumores malignos no Brasil. Confira!",
        "id": "508638082532356_1575958985800255"
      },
      {
        "created_time": "2017-10-08T00:00:00+0000",
        "message": "Saiba quais são os truques para que a maquiagem não envelheça seu visual:",
        "id": "508638082532356_1575329109196576"
      },
      {
        "created_time": "2017-10-07T22:30:00+0000",
        "message": "Você sabia que peles oleosas também podem ser sensíveis? Experimente Effaclar Alta Tolerância, sem sabão, sem álcool e sem parabenos.",
        "id": "508638082532356_1575277399201747"
      },
      {
        "created_time": "2017-10-07T17:00:00+0000",
        "message": "Esportes aquáticos tendem a deixar a pele ressecada, mas temos um time de produtos que pode te ajudar: Água Termal de La Roche-Posay, Hidratante Corporal Lipikar Loção e Sabonete Corporal Líquido Lipikar Surgras! Experimente sua pele sempre macia e hidratada!",
        "id": "508638082532356_1575020622560758"
      },
      {
        "created_time": "2017-10-07T14:30:00+0000",
        "message": "Você mantém sua pele protegida contra os efeitos da exposição solar ao longo do dia?",
      {
        "created_time": "2017-10-03T14:00:01+0000",
        "message": "Você sabia que o diagnóstico precoce do câncer de mama pode aumentar as chances de cura para até 95%? A prevenção e o diagnóstico precoce são assuntos que não podem ser deixados de lado! O mês de outubro é destinado à conscientização do câncer de mama, mas esse alerta vale para o ano todo!",
        "id": "508638082532356_1571116789617808"
      },
      {
        "created_time": "2017-10-03T00:20:00+0000",
        "message": "Você conhece os tipos de manchas na pele? Confira:",
        "id": "508638082532356_1570647952998025"
      },
      {
        "created_time": "2017-10-02T22:00:00+0000",
        "message": "Quais são os itens La-Roche Posay que não podem faltar na sua necessaire? Conta pra gente!",
        "id": "508638082532356_1570558239673663"
      },
      {
        "created_time": "2017-10-02T20:50:57+0000",
        "message": "Conheça truques para deixar o cabelo secar ao natural:",
        "id": "508638082532356_1570512396344914"
      },
      {
        "created_time": "2017-10-02T19:15:00+0000",
        "message": "Lipikar Creme AOX de La Roche-Posay é um hidratante corporal de textura leve e não pegajosa, com ação antioxidante e com alta proteção contra as raios UVA e UVB. Experimente!",
        "id": "508638082532356_1570443316351822"
      },
      {
        "created_time": "2017-09-30T17:15:00+0000",
        "message": "Effaclar Concentrado é um gel de limpeza diária que equilibra os níveis de oleosidade do rosto. Experimente usá-lo de uma a duas vezes ao dia e sinta na pele seus benefícios! 😉",
        "id": "508638082532356_1568532439876243"
      },
      {
        "created_time": "2017-09-27T23:45:00+0000",
        "message": "Serozinc age de maneira imediata na pele, matificando e reduzindo os poros e, usando continuamente, equilibra os níveis de oleosidade na pele. Experimente! Conheça mais em: http://spr.ly/618682HPO",
        "id": "508638082532356_1566055976790556"
      },
      {
        "created_time": "2017-09-27T21:30:00+0000",
        "message": "Com múltiplos benefícios, Serozinc atua na pele oleosa de forma completa. Confira sua ação e experimente! Conheça mais em: http://spr.ly/618682HPO",
        "id": "508638082532356_1566054903457330"
      },
      {
        "created_time": "2017-09-27T14:59:27+0000",
        "message": "Você sabe os benefícios que Serozinc pode trazer para sua pele? Muito além de um matificante, um cuidado! Experimente. 😉 Conheça mais em: http://spr.ly/61858N91B",
        "id": "508638082532356_1565803493482471"
      },
      {
        "created_time": "2017-09-27T00:15:00+0000",
        "message": "Você sabe os motivos que deixam sua pele oleosa? Confira:",
        "id": "508638082532356_1565224130207074"
      },
      {
        "created_time": "2017-09-26T21:00:00+0000",
        "message": "Serozinc te ajuda a manter o rosto livre da oleosidade, sem tirar a maquiagem! Aplique ao longo dia dia, sempre que sentir necessidade. Experimente! Conheça mais em: http://spr.ly/61878N9BL",
        "id": "508638082532356_1565082100221277"
      },
      {
        "created_time": "2017-09-26T19:30:00+0000",
        "message": "A finalização que faltava para a rotina da pele oleosa: Serozinc! Depois da limpeza e tratamento, borrife e matifique! #OndaAzul Confira mais em: http://spr.ly/61808N58o",
        "id": "508638082532356_1565016873561133"
      },
      {
        "created_time": "2017-09-25T00:00:00+0000",
        "message": "Conheça as vantagens do zinco para a pele oleosa e saiba onde encontrá-lo no dia a dia:",
        "id": "508638082532356_1563413770388110"
      },
      {
        "created_time": "2017-09-24T16:00:00+0000",
        "message": "Seu dia com a refrescância de Serozinc! Borrife ao longo do dia para refrescar, purificar e matificar. Conheça mais em: http://spr.ly/618682HPO",
        "id": "508638082532356_1563107520418735"
      },
      {
        "created_time": "2017-09-23T23:00:00+0000",
        "message": "Adulto também pode ter espinha? Confira:",
        "id": "508638082532356_1562445137151640"
      }
]

# %%
result = c.insert_many(posts)

# %%
result.inserted_ids
# Out:
# [ObjectId('59fdc577439a701bac843669'),
#  ObjectId('59fdc577439a701bac84366a'),
#  ObjectId('59fdc577439a701bac84366b'),
#  ObjectId('59fdc577439a701bac84366c'),
#  ObjectId('59fdc577439a701bac84366d'),
#  ObjectId('59fdc577439a701bac84366e'),
#  ObjectId('59fdc577439a701bac84366f'),
#  ObjectId('59fdc577439a701bac843670'),
#  ObjectId('59fdc577439a701bac843671'),
#  ObjectId('59fdc577439a701bac843672'),
#  ObjectId('59fdc577439a701bac843673'),
#  ObjectId('59fdc577439a701bac843674'),
#  ObjectId('59fdc577439a701bac843675'),
#  ObjectId('59fdc577439a701bac843676'),
#  ObjectId('59fdc577439a701bac843677'),
#  ObjectId('59fdc577439a701bac843678'),
#  ObjectId('59fdc577439a701bac843679'),
#  ObjectId('59fdc577439a701bac84367a'),
#  ObjectId('59fdc577439a701bac84367b'),
#  ObjectId('59fdc577439a701bac84367c'),
#  ObjectId('59fdc577439a701bac84367d'),
#  ObjectId('59fdc577439a701bac84367e'),
#  ObjectId('59fdc577439a701bac84367f'),
#  ObjectId('59fdc577439a701bac843680'),
# ...

# %%
import pprint
for posts in c.find():
 pprint.pprint(posts)
# Out:
# {'_id': ObjectId('59fdb514439a701bac843668'),
#  'about': 'Um canal de troca de experiências e dicas de saúde para quem sabe '
#           'que uma pele bem cuidada é a base de qualquer beleza. Visite: '
#           'www.laroche-posay.com.br',
#  'birthday': '04/29/2013',
#  'category': 'Beauty Store',
#  'fan_count': 4956858,
#  'global_brand_page_name': 'La Roche-Posay',
#  'id': '508638082532356',
#  'name': 'La Roche-Posay',
#  'products': 'Com uma experiência de mais de 30 anos de pesquisa e 25 '
#              'patentes, a La Roche-Posay se tornou referência no '
#              'desenvolvimento de produtos dedicados à pele, principalmente as '
#              'mais sensíveis. As soluções vão desde cuidados para o rosto e '
#              'corpo até maquiagem e cabelos. Veja as nossas linhas: '
#              'http://bit.ly/10hYJkm',
#  'talking_about_count': 53592,
#  'username': 'LaRocheBrasil',
#  'website': 'http://www.laroche-posay.com.br'}
# ...

# %%
p = db.posts

# %%
result = p.insert_many(posts)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-17312f40c00e> in <module>()
# ----> 1 result = p.insert_many(posts)
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in insert_many(self, documents, ordered, bypass_document_validation)
#     721
#     722         blk = _Bulk(self, ordered, bypass_document_validation)
# --> 723         blk.ops = [doc for doc in gen()]
#     724         blk.execute(self.write_concern.document)
#     725         return InsertManyResult(inserted_ids, self.write_concern.acknowledged)
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in <listcomp>(.0)
#     721
#     722         blk = _Bulk(self, ordered, bypass_document_validation)
# --> 723         blk.ops = [doc for doc in gen()]
#     724         blk.execute(self.write_concern.document)
# ...
